# %%
import pandas as pd

# %%
data = '/content/excess_mortality.csv'
df= pd.read_csv(data)
print (df)
# Out:
#            location        date  p_scores_all_ages  p_scores_15_64  \
# 0           Austria  2020-01-05             -10.83           -4.99
# 1           Austria  2020-01-12              -8.35           -1.45
# 2           Austria  2020-01-19               0.59           -7.32
# 3           Austria  2020-01-26               1.83           14.20
# 4           Austria  2020-02-02               7.06           -5.91
# ...             ...         ...                ...             ...
# 2036  United States  2020-12-27                NaN             NaN
# 2037  United States  2021-01-03                NaN             NaN
# 2038  United States  2021-01-10                NaN             NaN
# 2039  United States  2021-01-17                NaN             NaN
# 2040  United States  2021-01-24                NaN             NaN
#
#       p_scores_65_74  p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 0             -23.21           -5.11           -11.17                1613.0
# ...

# %%
df.shape
# Out:
# (2041, 21)

# %%
df.dropna(inplace = True)
df.head(5)
# Out:
#      location        date  p_scores_all_ages  p_scores_15_64  p_scores_65_74  \
# 0     Austria  2020-01-05             -10.83           -4.99          -23.21
# 1     Austria  2020-01-12              -8.35           -1.45           -5.43
# 56    Belgium  2020-01-05              -6.17           -6.12            0.11
# 112  Bulgaria  2020-01-05             -18.36          -22.02          -14.72
# 113  Bulgaria  2020-01-12             -11.59          -11.42           -3.57
#
#      p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 0             -5.11           -11.17                1613.0
# 1             -5.30           -13.40                1702.0
# 56           -12.40            -4.27                2243.0
# 112          -20.54           -15.69                2110.0
# 113          -17.68           -11.58                2276.0
#
#      average_deaths_2015_2019_all_ages  deaths_2015_all_ages  ...  \
# 0                               1809.0                1704.0  ...
# ...

# %%
df.describe()
# Out:
#        p_scores_all_ages  p_scores_15_64  p_scores_65_74  p_scores_75_84  \
# count          27.000000       27.000000       27.000000       27.000000
# mean           -5.159630       -6.440741       -3.147407       -7.977778
# std             5.842685        6.984323        9.057819        9.992375
# min           -18.360000      -22.020000      -23.210000      -33.470000
# 25%            -9.040000      -11.865000       -6.920000      -15.290000
# 50%            -5.230000       -7.700000       -3.570000       -6.730000
# 75%            -0.550000       -0.845000        2.460000        1.055000
# max             7.890000       10.220000       17.290000        8.860000
#
#        p_scores_85plus  deaths_2020_all_ages  \
# count        27.000000             27.000000
# mean         -2.430741           3250.148148
# std           8.540770           3766.055289
# min         -15.690000            296.000000
# 25%          -9.430000           1104.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 1790
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   location                           27 non-null     object
#  1   date                               27 non-null     object
#  2   p_scores_all_ages                  27 non-null     float64
#  3   p_scores_15_64                     27 non-null     float64
#  4   p_scores_65_74                     27 non-null     float64
#  5   p_scores_75_84                     27 non-null     float64
#  6   p_scores_85plus                    27 non-null     float64
#  7   deaths_2020_all_ages               27 non-null     float64
#  8   average_deaths_2015_2019_all_ages  27 non-null     float64
#  9   deaths_2015_all_ages               27 non-null     float64
#  10  deaths_2016_all_ages               27 non-null     float64
# ...

# %%
df.isna().sum()
# Out:
# location                             0
# date                                 0
# p_scores_all_ages                    0
# p_scores_15_64                       0
# p_scores_65_74                       0
# p_scores_75_84                       0
# p_scores_85plus                      0
# deaths_2020_all_ages                 0
# average_deaths_2015_2019_all_ages    0
# deaths_2015_all_ages                 0
# deaths_2016_all_ages                 0
# deaths_2017_all_ages                 0
# deaths_2018_all_ages                 0
# deaths_2019_all_ages                 0
# deaths_2010_all_ages                 0
# deaths_2011_all_ages                 0
# deaths_2012_all_ages                 0
# deaths_2013_all_ages                 0
# deaths_2014_all_ages                 0
# Week                                 0
# deaths_2021_all_ages                 0
# dtype: int64

# %%
df1 = df[['location','deaths_2020_all_ages','deaths_2019_all_ages']]
df1.head(10)
# Out:
#             location  deaths_2020_all_ages  deaths_2019_all_ages
# 0            Austria                1613.0                1647.0
# 1            Austria                1702.0                1709.0
# 56           Belgium                2243.0                2308.0
# 112         Bulgaria                2110.0                2533.0
# 113         Bulgaria                2276.0                2692.0
# 392          Denmark                1117.0                1130.0
# 393          Denmark                1150.0                1155.0
# 394          Denmark                1071.0                1118.0
# 448  England & Wales               12253.0               10955.0
# 449  England & Wales               14057.0               12609.0

# %%
df1['deaths_difference']= df1['deaths_2020_all_ages']-df1['deaths_2019_all_ages']
df1.head(10)
# Out:
# <ipython-input-9-2d688c958df1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['deaths_difference']= df1['deaths_2020_all_ages']-df1['deaths_2019_all_ages']
#             location  deaths_2020_all_ages  deaths_2019_all_ages  \
# 0            Austria                1613.0                1647.0
# 1            Austria                1702.0                1709.0
# 56           Belgium                2243.0                2308.0
# 112         Bulgaria                2110.0                2533.0
# 113         Bulgaria                2276.0                2692.0
# 392          Denmark                1117.0                1130.0
# 393          Denmark                1150.0                1155.0
# ...

# %%
df.columns
# Out:
# Index(['location', 'date', 'p_scores_all_ages', 'p_scores_15_64',
#        'p_scores_65_74', 'p_scores_75_84', 'p_scores_85plus',
#        'deaths_2020_all_ages', 'average_deaths_2015_2019_all_ages',
#        'deaths_2015_all_ages', 'deaths_2016_all_ages', 'deaths_2017_all_ages',
#        'deaths_2018_all_ages', 'deaths_2019_all_ages', 'deaths_2010_all_ages',
#        'deaths_2011_all_ages', 'deaths_2012_all_ages', 'deaths_2013_all_ages',
#        'deaths_2014_all_ages', 'Week', 'deaths_2021_all_ages'],
#       dtype='object')

# %%
df['deaths_2014_all_ages']
# Out:
# 0        1549.0
# 1        1543.0
# 56       2214.0
# 112      2302.0
# 113      2246.0
# 392      1025.0
# 393      1017.0
# 394      1050.0
# 448     11448.0
# 449     11845.0
# 504       302.0
# 505       308.0
# 894       918.0
# 1006      561.0
# 1007      593.0
# 1062      777.0
# 1174     2770.0
# 1175     2820.0
# 1176     2742.0
# 1398     7533.0
# 1454     2566.0
# 1510     1090.0
# 1511     1313.0
# 1512     1189.0
# 1734     9049.0
# 1735     9009.0
# 1790     1840.0
# Name: deaths_2014_all_ages, dtype: float64

# %%
df['location'].unique
# Out:
# <bound method Series.unique of 0               Austria
# 1               Austria
# 56              Belgium
# 112            Bulgaria
# 113            Bulgaria
# 392             Denmark
# 393             Denmark
# 394             Denmark
# 448     England & Wales
# 449     England & Wales
# 504             Estonia
# 505             Estonia
# 894              Israel
# 1006             Latvia
# 1007             Latvia
# 1062          Lithuania
# 1174        Netherlands
# 1175        Netherlands
# 1176        Netherlands
# 1398             Poland
# 1454           Portugal
# 1510           Scotland
# 1511           Scotland
# 1512           Scotland
# 1734              Spain
# 1735              Spain
# 1790             Sweden
# Name: location, dtype: object>

# %%
df.head()
# Out:
#      location        date  p_scores_all_ages  p_scores_15_64  p_scores_65_74  \
# 0     Austria  2020-01-05             -10.83           -4.99          -23.21
# 1     Austria  2020-01-12              -8.35           -1.45           -5.43
# 56    Belgium  2020-01-05              -6.17           -6.12            0.11
# 112  Bulgaria  2020-01-05             -18.36          -22.02          -14.72
# 113  Bulgaria  2020-01-12             -11.59          -11.42           -3.57
#
#      p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 0             -5.11           -11.17                1613.0
# 1             -5.30           -13.40                1702.0
# 56           -12.40            -4.27                2243.0
# 112          -20.54           -15.69                2110.0
# 113          -17.68           -11.58                2276.0
#
#      average_deaths_2015_2019_all_ages  deaths_2015_all_ages  ...  \
# 0                               1809.0                1704.0  ...
# ...

# %%
df2=df[['location','average_deaths_2015_2019_all_ages']]
df2.head(10)
# Out:
#             location  average_deaths_2015_2019_all_ages
# 0            Austria                             1809.0
# 1            Austria                             1857.0
# 56           Belgium                             2390.4
# 112         Bulgaria                             2584.6
# 113         Bulgaria                             2574.4
# 392          Denmark                             1121.4
# 393          Denmark                             1115.0
# 394          Denmark                             1102.4
# 448  England & Wales                            12198.8
# 449  England & Wales                            13821.6

# %%
from statistics import mean

# %%
len(df2)
# Out:
# 27

# %%
Keys=[]
value=[]


for i in df2['location']: 
  vals=[]
  count=0
  if (i != Keys):
    Keys.append(i)
    for j in df2['location']:
      if i==j:
        vals.append(df2.iloc[count,1])
      count+=1
    value.append(mean(vals))

res = {Keys[i]: value[i] for i in range(len(value))}


print(Keys,value)
print(res)
# Out:
# ['Austria', 'Austria', 'Belgium', 'Bulgaria', 'Bulgaria', 'Denmark', 'Denmark', 'Denmark', 'England & Wales', 'England & Wales', 'Estonia', 'Estonia', 'Israel', 'Latvia', 'Latvia', 'Lithuania', 'Netherlands', 'Netherlands', 'Netherlands', 'Poland', 'Portugal', 'Scotland', 'Scotland', 'Scotland', 'Spain', 'Spain', 'Sweden'] [1833.0, 1833.0, 2390.4, 2579.5, 2579.5, 1112.9333333333334, 1112.9333333333334, 1112.9333333333334, 13010.2, 13010.2, 344.3, 344.3, 1011.2, 615.7, 615.7, 863.0, 3308.4666666666667, 3308.4666666666667, 3308.4666666666667, 8503.6, 2794.4, 1405.8666666666666, 1405.8666666666666, 1405.8666666666666, 10075.0, 10075.0, 1975.4]
# {'Austria': 1833.0, 'Belgium': 2390.4, 'Bulgaria': 2579.5, 'Denmark': 1112.9333333333334, 'England & Wales': 13010.2, 'Estonia': 344.3, 'Israel': 1011.2, 'Latvia': 615.7, 'Lithuania': 863.0, 'Netherlands': 3308.4666666666667, 'Poland': 8503.6, 'Portugal': 2794.4, 'Scotland': 1405.8666666666666, 'Spain': 10075.0, 'Sweden': 1975.4}

# %%
my_dict_2 = {key: val for key, val in sorted(res.items(), key = lambda ele: ele[1], reverse = True)}
my_dict_2
# Out:
# {'England & Wales': 13010.2,
#  'Spain': 10075.0,
#  'Poland': 8503.6,
#  'Netherlands': 3308.4666666666667,
#  'Portugal': 2794.4,
#  'Bulgaria': 2579.5,
#  'Belgium': 2390.4,
#  'Sweden': 1975.4,
#  'Austria': 1833.0,
#  'Scotland': 1405.8666666666666,
#  'Denmark': 1112.9333333333334,
#  'Israel': 1011.2,
#  'Lithuania': 863.0,
#  'Latvia': 615.7,
#  'Estonia': 344.3}
