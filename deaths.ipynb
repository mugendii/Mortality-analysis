# %%
import pandas as pd
from statistics import mean

# %%
data = 'excess_mortality.csv'
df= pd.read_csv(data)
df
# Out:
#            location        date  p_scores_all_ages  p_scores_15_64  \
# 0           Austria  2020-01-05             -10.83           -4.99
# 1           Austria  2020-01-12              -8.35           -1.45
# 2           Austria  2020-01-19               0.59           -7.32
# 3           Austria  2020-01-26               1.83           14.20
# 4           Austria  2020-02-02               7.06           -5.91
# ...             ...         ...                ...             ...
# 2036  United States  2020-12-27                NaN             NaN
# 2037  United States  2021-01-03                NaN             NaN
# 2038  United States  2021-01-10                NaN             NaN
# 2039  United States  2021-01-17                NaN             NaN
# 2040  United States  2021-01-24                NaN             NaN
#
#       p_scores_65_74  p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 0             -23.21           -5.11           -11.17                1613.0
# ...

# %%
df.shape
# Out:
# (2041, 21)

# %%
df.dropna(inplace = True)
df.head(5)
# Out:
#      location        date  p_scores_all_ages  p_scores_15_64  p_scores_65_74  \
# 0     Austria  2020-01-05             -10.83           -4.99          -23.21
# 1     Austria  2020-01-12              -8.35           -1.45           -5.43
# 56    Belgium  2020-01-05              -6.17           -6.12            0.11
# 112  Bulgaria  2020-01-05             -18.36          -22.02          -14.72
# 113  Bulgaria  2020-01-12             -11.59          -11.42           -3.57
#
#      p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 0             -5.11           -11.17                1613.0
# 1             -5.30           -13.40                1702.0
# 56           -12.40            -4.27                2243.0
# 112          -20.54           -15.69                2110.0
# 113          -17.68           -11.58                2276.0
#
#      average_deaths_2015_2019_all_ages  deaths_2015_all_ages  ...  \
# 0                               1809.0                1704.0  ...
# ...

# %%
df.describe()
# Out:
#        p_scores_all_ages  p_scores_15_64  p_scores_65_74  p_scores_75_84  \
# count          27.000000       27.000000       27.000000       27.000000
# mean           -5.159630       -6.440741       -3.147407       -7.977778
# std             5.842685        6.984323        9.057819        9.992375
# min           -18.360000      -22.020000      -23.210000      -33.470000
# 25%            -9.040000      -11.865000       -6.920000      -15.290000
# 50%            -5.230000       -7.700000       -3.570000       -6.730000
# 75%            -0.550000       -0.845000        2.460000        1.055000
# max             7.890000       10.220000       17.290000        8.860000
#
#        p_scores_85plus  deaths_2020_all_ages  \
# count        27.000000             27.000000
# mean         -2.430741           3250.148148
# std           8.540770           3766.055289
# min         -15.690000            296.000000
# 25%          -9.430000           1104.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 1790
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   location                           27 non-null     object
#  1   date                               27 non-null     object
#  2   p_scores_all_ages                  27 non-null     float64
#  3   p_scores_15_64                     27 non-null     float64
#  4   p_scores_65_74                     27 non-null     float64
#  5   p_scores_75_84                     27 non-null     float64
#  6   p_scores_85plus                    27 non-null     float64
#  7   deaths_2020_all_ages               27 non-null     float64
#  8   average_deaths_2015_2019_all_ages  27 non-null     float64
#  9   deaths_2015_all_ages               27 non-null     float64
#  10  deaths_2016_all_ages               27 non-null     float64
# ...

# %%
df.isna().sum()
# Out:
# location                             0
# date                                 0
# p_scores_all_ages                    0
# p_scores_15_64                       0
# p_scores_65_74                       0
# p_scores_75_84                       0
# p_scores_85plus                      0
# deaths_2020_all_ages                 0
# average_deaths_2015_2019_all_ages    0
# deaths_2015_all_ages                 0
# deaths_2016_all_ages                 0
# deaths_2017_all_ages                 0
# deaths_2018_all_ages                 0
# deaths_2019_all_ages                 0
# deaths_2010_all_ages                 0
# deaths_2011_all_ages                 0
# deaths_2012_all_ages                 0
# deaths_2013_all_ages                 0
# deaths_2014_all_ages                 0
# Week                                 0
# deaths_2021_all_ages                 0
# dtype: int64

# %% [markdown]
#  Create a DataFrame that consists of the following columns: (1) location; (2) deaths in 2020; (3)deaths in 2019; (4) the difference between deaths in 2020 and 2019. The location column should include the name of the respective country.

# %%
df1 = df[['location','deaths_2020_all_ages','deaths_2019_all_ages']]
df1.head(10)
# Out:
#             location  deaths_2020_all_ages  deaths_2019_all_ages
# 0            Austria                1613.0                1647.0
# 1            Austria                1702.0                1709.0
# 56           Belgium                2243.0                2308.0
# 112         Bulgaria                2110.0                2533.0
# 113         Bulgaria                2276.0                2692.0
# 392          Denmark                1117.0                1130.0
# 393          Denmark                1150.0                1155.0
# 394          Denmark                1071.0                1118.0
# 448  England & Wales               12253.0               10955.0
# 449  England & Wales               14057.0               12609.0

# %%
df1['deaths_difference']= df1['deaths_2020_all_ages']-df1['deaths_2019_all_ages']
df1.head(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7892\2031578536.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['deaths_difference']= df1['deaths_2020_all_ages']-df1['deaths_2019_all_ages']
#             location  deaths_2020_all_ages  deaths_2019_all_ages  \
# 0            Austria                1613.0                1647.0
# 1            Austria                1702.0                1709.0
# 56           Belgium                2243.0                2308.0
# 112         Bulgaria                2110.0                2533.0
# 113         Bulgaria                2276.0                2692.0
# 392          Denmark                1117.0                1130.0
# 393          Denmark                1150.0                1155.0
# ...

# %% [markdown]
#  Find all the countries showing excess deaths. Excess deaths is defined as the difference between the deaths occurred in a specific week in 2020 vs 2019. Hint: the diff between 2020 and 2019 has to be greater than 0.

# %%
df.loc[df1['deaths_difference'] > 0]
# Out:
#              location        date  p_scores_all_ages  p_scores_15_64  \
# 448   England & Wales  2020-01-05               0.44           -8.15
# 449   England & Wales  2020-01-12               1.70            1.31
# 894            Israel  2020-01-05               7.89            1.70
# 1006           Latvia  2020-01-05              -2.45          -14.60
# 1174      Netherlands  2020-01-05              -5.45          -12.69
# 1175      Netherlands  2020-01-12               0.34           -0.05
# 1176      Netherlands  2020-01-19              -4.01           -2.90
# 1510         Scotland  2020-01-05              -8.93           -8.44
# 1511         Scotland  2020-01-12               0.47            1.63
#
#       p_scores_65_74  p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 448            -3.59            2.90             2.89               12253.0
# 449             0.26            3.35             1.46               14057.0
# ...

# %%
df1.loc[df1['deaths_difference'] > 0]
# Out:
#              location  deaths_2020_all_ages  deaths_2019_all_ages  \
# 448   England & Wales               12253.0               10955.0
# 449   England & Wales               14057.0               12609.0
# 894            Israel                1091.0                 969.0
# 1006           Latvia                 597.0                 586.0
# 1174      Netherlands                3103.0                3061.0
# 1175      Netherlands                3365.0                3261.0
# 1176      Netherlands                3158.0                3153.0
# 1510         Scotland                1162.0                1104.0
# 1511         Scotland                1567.0                1507.0
#
#       deaths_difference
# 448              1298.0
# 449              1448.0
# 894               122.0
# 1006               11.0
# 1174               42.0
# 1175              104.0
# 1176                5.0
# 1510               58.0
# 1511               60.0

# %% [markdown]
# QUESTION 4

# %% [markdown]
# For each country, find which year had the lowest mortality

# %%
Austria_df =df.loc[df['location'] == 'Austria']
Austria_df
# Out:
#   location        date  p_scores_all_ages  p_scores_15_64  p_scores_65_74  \
# 0  Austria  2020-01-05             -10.83           -4.99          -23.21
# 1  Austria  2020-01-12              -8.35           -1.45           -5.43
#
#    p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 0           -5.11           -11.17                1613.0
# 1           -5.30           -13.40                1702.0
#
#    average_deaths_2015_2019_all_ages  deaths_2015_all_ages  ...  \
# 0                             1809.0                1704.0  ...
# 1                             1857.0                1768.0  ...
#
#    deaths_2017_all_ages  deaths_2018_all_ages  deaths_2019_all_ages  \
# 0                2293.0                1767.0                1647.0
# 1                2340.0                1842.0                1709.0
#
#    deaths_2010_all_ages  deaths_2011_all_ages  deaths_2012_all_ages  \
# 0                1557.0                1579.0                1574.0
# ...

# %%
#removing unwanted columns
Austria_df = Austria_df.drop(['p_scores_all_ages','p_scores_15_64','p_scores_65_74','p_scores_75_84','p_scores_85plus','average_deaths_2015_2019_all_ages','Week'], axis=1)
Austria_df
# Out:
#   location        date  deaths_2020_all_ages  deaths_2015_all_ages  \
# 0  Austria  2020-01-05                1613.0                1704.0
# 1  Austria  2020-01-12                1702.0                1768.0
#
#    deaths_2016_all_ages  deaths_2017_all_ages  deaths_2018_all_ages  \
# 0                1634.0                2293.0                1767.0
# 1                1626.0                2340.0                1842.0
#
#    deaths_2019_all_ages  deaths_2010_all_ages  deaths_2011_all_ages  \
# 0                1647.0                1557.0                1579.0
# 1                1709.0                1582.0                1671.0
#
#    deaths_2012_all_ages  deaths_2013_all_ages  deaths_2014_all_ages  \
# 0                1574.0                1637.0                1549.0
# 1                1563.0                1659.0                1543.0
#
#    deaths_2021_all_ages
# 0                1944.0
# 1                1941.0

# %%
Austria_df.mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7892\1519750470.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Austria_df.mean()
# deaths_2020_all_ages    1657.5
# deaths_2015_all_ages    1736.0
# deaths_2016_all_ages    1630.0
# deaths_2017_all_ages    2316.5
# deaths_2018_all_ages    1804.5
# deaths_2019_all_ages    1678.0
# deaths_2010_all_ages    1569.5
# deaths_2011_all_ages    1625.0
# deaths_2012_all_ages    1568.5
# deaths_2013_all_ages    1648.0
# deaths_2014_all_ages    1546.0
# deaths_2021_all_ages    1942.5
# dtype: float64

# %%
Average_deaths = Austria_df.mean()
Lowest_mortality = Average_deaths.min()
print(Lowest_mortality)
min_col = Average_deaths.idxmin()

# Get the actual minimum value
min_val = df[min_col].min()

print(f"The column with the lowest mean is '{min_col}', with a mean of {Average_deaths[min_col]} and a minimum value of {min_val}.")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7892\449455149.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Average_deaths = Austria_df.mean()
# 1546.0
# The column with the lowest mean is 'deaths_2014_all_ages', with a mean of 1546.0 and a minimum value of 302.0.

# %%
Belgium_df =df.loc[df['location'] == 'Belgium']
Belgium_df
# Out:
#    location        date  p_scores_all_ages  p_scores_15_64  p_scores_65_74  \
# 56  Belgium  2020-01-05              -6.17           -6.12            0.11
#
#     p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 56           -12.4            -4.27                2243.0
#
#     average_deaths_2015_2019_all_ages  deaths_2015_all_ages  ...  \
# 56                             2390.4                2461.0  ...
#
#     deaths_2017_all_ages  deaths_2018_all_ages  deaths_2019_all_ages  \
# 56                2557.0                2382.0                2308.0
#
#     deaths_2010_all_ages  deaths_2011_all_ages  deaths_2012_all_ages  \
# 56                2280.0                2334.0                2286.0
#
#     deaths_2013_all_ages  deaths_2014_all_ages  Week  deaths_2021_all_ages
# 56                2236.0                2214.0     1                2423.0
#
# [1 rows x 21 columns]

# %%
Belgium_df = Belgium_df.drop(['p_scores_all_ages','p_scores_15_64','p_scores_65_74','p_scores_75_84','p_scores_85plus','average_deaths_2015_2019_all_ages','Week'], axis=1)
Belgium_df
# Out:
#    location        date  deaths_2020_all_ages  deaths_2015_all_ages  \
# 56  Belgium  2020-01-05                2243.0                2461.0
#
#     deaths_2016_all_ages  deaths_2017_all_ages  deaths_2018_all_ages  \
# 56                2244.0                2557.0                2382.0
#
#     deaths_2019_all_ages  deaths_2010_all_ages  deaths_2011_all_ages  \
# 56                2308.0                2280.0                2334.0
#
#     deaths_2012_all_ages  deaths_2013_all_ages  deaths_2014_all_ages  \
# 56                2286.0                2236.0                2214.0
#
#     deaths_2021_all_ages
# 56                2423.0

# %%
Belgium_df.mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7892\4040423585.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Belgium_df.mean()
# deaths_2020_all_ages    2243.0
# deaths_2015_all_ages    2461.0
# deaths_2016_all_ages    2244.0
# deaths_2017_all_ages    2557.0
# deaths_2018_all_ages    2382.0
# deaths_2019_all_ages    2308.0
# deaths_2010_all_ages    2280.0
# deaths_2011_all_ages    2334.0
# deaths_2012_all_ages    2286.0
# deaths_2013_all_ages    2236.0
# deaths_2014_all_ages    2214.0
# deaths_2021_all_ages    2423.0
# dtype: float64

# %%
Average_deaths = Belgium_df.mean()
Lowest_mortality = Average_deaths.min()
print(Lowest_mortality)
min_col = Average_deaths.idxmin()

# Get the actual minimum value
min_val = df[min_col].min()

print(f"The column with the lowest mean is '{min_col}', with a mean of {Average_deaths[min_col]} and a minimum value of {min_val}.")
# Out:
# 2214.0
# The column with the lowest mean is 'deaths_2014_all_ages', with a mean of 2214.0 and a minimum value of 302.0.
# C:\Users\User\AppData\Local\Temp\ipykernel_7892\2325534030.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Average_deaths = Belgium_df.mean()

# %%
df2 = df[['location','deaths_2020_all_ages','deaths_2019_all_ages','deaths_2018_all_ages','deaths_2017_all_ages','deaths_2016_all_ages','deaths_2015_all_ages','deaths_2014_all_ages','deaths_2013_all_ages','deaths_2012_all_ages','deaths_2011_all_ages','deaths_2010_all_ages']]
df2
# Out:
#              location  deaths_2020_all_ages  deaths_2019_all_ages  \
# 0             Austria                1613.0                1647.0
# 1             Austria                1702.0                1709.0
# 56            Belgium                2243.0                2308.0
# 112          Bulgaria                2110.0                2533.0
# 113          Bulgaria                2276.0                2692.0
# 392           Denmark                1117.0                1130.0
# 393           Denmark                1150.0                1155.0
# 394           Denmark                1071.0                1118.0
# 448   England & Wales               12253.0               10955.0
# 449   England & Wales               14057.0               12609.0
# 504           Estonia                 296.0                 351.0
# 505           Estonia                 331.0                 338.0
# 894            Israel                1091.0                 969.0
# ...

# %%
import math

# %%
#creating a dictionary to store each location and its values as key and value pairsfrom statistics import mean

my_dict = {}
keys= []
values = []

for i in df2['location']:
    vals= []
    count = 0
    if i != keys:
        keys.append(i)
        for j in df2['location']:
            if i == j:
                vals.append(mean(vals))
res = {keys[i]:vals[i]for i in range (len(values))}
print(res)
print(keys,vals)
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# Cell In [40], line 14
#      12         for j in df2['location']:
#      13             if i == j:
# ---> 14                 vals.append(mean(vals))
#      15 res = {keys[i]:vals[i]for i in range (len(values))}
#      16 print(res)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\statistics.py:328, in mean(data)
#     326 n = len(data)
#     327 if n < 1:
# --> 328     raise StatisticsError('mean requires at least one data point')
#     329 T, total, count = _sum(data)
#     330 assert count == n
#
# StatisticsError: mean requires at least one data point
